# %%
# https://www.knowledgehut.com/blog/data-science/types-of-classification-in-ml
from sklearn.datasets import make_blobs 
from collections import Counter 
from numpy import where 
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# GLOBAL VARIABLE 
DATASET_NAME="iris"

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import pickle

def load_datasets(datasets_name="iris"):
    if datasets_name == "iris":
        dataset = datasets.load_iris()

    X = dataset.data
    y = dataset.target

    y_ = y.reshape(-1, 1) # Convert data to a single column

    # One Hot encode the class labels
    encoder = OneHotEncoder(sparse=False)
    y = encoder.fit_transform(y_)

    # Split the data for training and testing
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    return x_train, x_test, y_train, y_test

def saveReport(accuracy_history):
    data = {
        "accuracy_history": accuracy_history
    }
    pickle.dump(data, open("./GA_report.pkl", "wb"))

x_train, x_test, y_train, y_test = load_datasets(DATASET_NAME)

# %%
import random
import numpy as np
import pandas as pd
import copy
import time
from numpy import exp
from sklearn.preprocessing import OneHotEncoder

random.seed(42)
np.random.seed(42)

class Network(object):

    def __init__(self, sizes):
        
        '''The list ``sizes`` contains the number of neurons in the
        respective layers of the network.  For example, if the list
        was [2, 3, 1] then it would be a three-layer network, with the
        first layer containing 2 neurons, the second layer 3 neurons,
        and the third layer 1 neuron.  The biases and weights for the
        network are initialized randomly, using a Gaussian
        distribution with mean 0, and variance 1.  Note that the first
        layer is assumed to be an input layer, and by convention we
        won't set any biases for those neurons, since biases are only
        ever used in computing the outputs from later layers.'''

        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
        
        # helper variables
        self.bias_nitem = sum(sizes[1:])
        self.weight_nitem = sum([self.weights[i].size for i in range(self.num_layers-2)])

    def feedforward(self, a):
        '''Return the output of the network if ``a`` is input.'''
        for b, w in zip(self.biases, self.weights):
            a = self.sigmoid(np.dot(w,a)+b)
        return a

    # Actifation Functions
    def softmax(self, z):
        e = exp(z)
        e_sum = e.sum()
        if e_sum == 0:
            e_sum = 1
        return e / e_sum

    def sigmoid(self, z):
        '''The sigmoid function.'''
        return 1.0/(1.0+np.exp(-z))

    def relu(self, z):
        def relu_func(x):
            return x if x > 0 else 0
        return np.array(list(map(relu_func, z)))

    def score(self, X, y):

        '''
        @X = data to test
        @y = data-label to test
        @returns = score of network prediction (less is better)
        @ref: https://stats.stackexchange.com/questions/154879/a-list-of-cost-functions-used-in-neural-networks-alongside-applications
        '''

        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            score = np.sum(np.power(predicted-actual,2))
            # print("Accuracy Argmax:", np.argmax(predicted), np.argmax(actual), "Score:",score)
            # txt ="[ "
            # for pred in predicted:
            #     txt += "{}, ".format(pred)
            # print(txt, "]", sum(predicted))
            total_score += score  # mean-squared error
        # total_score /= X.shape[0] 
        # print("Total Score:", total_score)
        return total_score

    def accuracy(self, X, y):

        '''
        @X = data to test
        @y = data-label to test
        @returns = accuracy (%) (more is better)
        '''

        accuracy = 0
        for i in range(X.shape[0]):
            output = self.feedforward(X[i].reshape(-1,1))
            accuracy += int(np.argmax(output) == np.argmax(y[i]))
        return (accuracy / X.shape[0]) * 100

    def __str__(self):
        s = "\nBias:\n\n" + str(self.biases)
        s += "\nWeights:\n\n" + str(self.weights)
        s += "\n\n"
        return s

class NNGeneticAlgo:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, retain_rate, X, y):

        '''
        n_pops   = How much population do our GA need to create
        net_size = Size of neural network for population members
        mutation_rate = probability of mutating all bias & weight inside our network
        crossover_rate = probability of cross-overing all bias & weight inside out network
        retain_rate = How many to retain our population for the best ones
        X = our data to test accuracy
        y = our data-label to test accuracy
        '''

        self.n_pops = n_pops
        self.net_size = net_size
        self.nets = [Network(self.net_size) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.retain_rate = retain_rate
        self.X = X[:]
        self.y = y[:]
    
    def get_random_point(self, type):

        '''
        @type = either 'weight' or 'bias'
        @returns tuple (layer_index, point_index)
            note: if type is set to 'weight', point_index will return (row_index, col_index)
        '''

        nn = self.nets[0]
        layer_index, point_index = random.randint(0, nn.num_layers-2), 0
        if type == 'weight':
            row = random.randint(0,nn.weights[layer_index].shape[0]-1)
            col = random.randint(0,nn.weights[layer_index].shape[1]-1)
            point_index = (row, col)
        elif type == 'bias':
            point_index = random.randint(0,nn.biases[layer_index].size-1)
        return (layer_index, point_index)

    def get_all_scores(self):
        return [net.score(self.X, self.y) for net in self.nets]

    def get_all_accuracy(self):
        return [net.accuracy(self.X, self.y) for net in self.nets]

    def crossover(self, father, mother):

        '''
        @father = neural-net object representing father
        @mother = neural-net object representing mother
        @returns = new child based on father/mother genetic information
        '''

        # make a copy of father 'genetic' weights & biases information
        nn = copy.deepcopy(father)

        # cross-over bias
        for _ in range(self.nets[0].bias_nitem):
            # get some random points
            layer, point = self.get_random_point('bias')
            # replace genetic (bias) with mother's value
            if random.uniform(0,1) < self.crossover_rate:
                nn.biases[layer][point] = mother.biases[layer][point]

        # cross-over weight
        for _ in range(self.nets[0].weight_nitem):
            # get some random points
            layer, point = self.get_random_point('weight')
            # replace genetic (weight) with mother's value
            if random.uniform(0,1) < self.crossover_rate:
                nn.weights[layer][point] = mother.weights[layer][point]
        
        return nn
        
    def mutation(self, child):

        '''
        @child_index = neural-net object to mutate its internal weights & biases value
        @returns = new mutated neural-net
        '''

        nn = copy.deepcopy(child)

        # mutate bias
        for _ in range(self.nets[0].bias_nitem):
            # get some random points
            layer, point = self.get_random_point('bias')
            # add some random value between -0.5 and 0.5
            if random.uniform(0,1) < self.mutation_rate:
                nn.biases[layer][point] += random.uniform(-0.5, 0.5)

        # mutate weight
        for _ in range(self.nets[0].weight_nitem):
            # get some random points
            layer, point = self.get_random_point('weight')
            # add some random value between -0.5 and 0.5
            if random.uniform(0,1) < self.mutation_rate:
                nn.weights[layer][point[0], point[1]] += random.uniform(-0.5, 0.5)

        return nn

    def evolve(self):

        # calculate score for each population of neural-net
        score_list = list(zip(self.nets, self.get_all_scores()))

        # sort the network using its score
        score_list.sort(key=lambda x: x[1])
        score_list = [obj[0] for obj in score_list]

        # keep only the best one
        retain_num = int(self.n_pops*self.retain_rate)
        score_list_top = score_list[:retain_num]

        # return some non-best ones
        retain_non_best = int((self.n_pops-retain_num) * self.retain_rate)
        for _ in range(random.randint(0, retain_non_best)):
            score_list_top.append(random.choice(score_list[retain_num:]))

        # breed new childs if current population number less than what we want
        while len(score_list_top) < self.n_pops:

            father = random.choice(score_list_top[:retain_num + retain_non_best])
            mother = random.choice(score_list_top[:retain_num + retain_non_best])

            if father != mother:
                new_child = self.crossover(father, mother)
                new_child = self.mutation(new_child)
                score_list_top.append(new_child)
        
        # copy our new population to current object
        self.nets = score_list_top

# %%
X = x_train
y = y_train

print(X.shape)
print(y.shape)

# parameters
N_POPS = 30
NET_SIZE = [X[0].shape[0],20,y[0].shape[0]] 
MUTATION_RATE = 0.2
CROSSOVER_RATE = 0.4
RETAIN_RATE = 0.4

EPOCH = 1000

# start our neural-net & optimize it using genetic algorithm
nnga = NNGeneticAlgo(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, RETAIN_RATE, X, y)

start_time = time.time()

# run for n iterations
accuracy_history = []
# for i in range(1000):
global_prev_best_accuracy = 0
max_count_after_best = 100
count_after_best = 0
for i in range(EPOCH):

    # accuracy = 
    best_current_accuracy = max(nnga.get_all_accuracy())
    if i % 1 == 0:
        print("Current iteration : {}".format(i+1))
        print("Time taken by far : %.1f seconds" % (time.time() - start_time))
        print("Current top member's network accuracy: %.2f%%\n" %best_current_accuracy)
        # print(nnga.get_all_accuracy())
        
    accuracy_history.append(best_current_accuracy)
    # if global_prev_best_accuracy < best_current_accuracy:
    #     global_prev_best_accuracy = best_current_accuracy
    #     count_after_best = 0
    # else:
    #     count_after_best += 1
    
    # if count_after_best > max_count_after_best:
    #     print("Early Stopped after", count_after_best, "without improvemnet from: ", global_prev_best_accuracy, "Current was:", best_current_accuracy)
    #     break

    # evolve the population
    nnga.evolve()

import numpy as np
import matplotlib.pyplot as plt
plt.plot(accuracy_history)
plt.show()
# Out:
# (120, 4)
# (120, 3)
# Current iteration : 1
# Time taken by far : 0.1 seconds
# Current top member's network accuracy: 65.83%
#
# Current iteration : 2
# Time taken by far : 0.3 seconds
# Current top member's network accuracy: 65.83%
#
# Current iteration : 3
# Time taken by far : 0.5 seconds
# Current top member's network accuracy: 65.83%
#
# Current iteration : 4
# Time taken by far : 0.7 seconds
# Current top member's network accuracy: 65.83%
#
# Current iteration : 5
# Time taken by far : 0.9 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 6
# Time taken by far : 1.1 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 7
# Time taken by far : 1.2 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 8
# Time taken by far : 1.4 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 9
# Time taken by far : 1.6 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 10
# Time taken by far : 1.8 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 11
# Time taken by far : 2.0 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 12
# Time taken by far : 2.1 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 13
# Time taken by far : 2.3 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 14
# Time taken by far : 2.5 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 15
# Time taken by far : 2.6 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 16
# Time taken by far : 2.8 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 17
# Time taken by far : 2.9 seconds
# Current top member's network accuracy: 77.50%
#
# Current iteration : 18
# Time taken by far : 3.1 seconds
# Current top member's network accuracy: 86.67%
#
# Current iteration : 19
# Time taken by far : 3.2 seconds
# Current top member's network accuracy: 86.67%
#
# Current iteration : 20
# Time taken by far : 3.4 seconds
# Current top member's network accuracy: 86.67%
#
# Current iteration : 21
# Time taken by far : 3.5 seconds
# Current top member's network accuracy: 93.33%
#
# Current iteration : 22
# Time taken by far : 3.7 seconds
# Current top member's network accuracy: 86.67%
#
# Current iteration : 23
# Time taken by far : 3.8 seconds
# Current top member's network accuracy: 86.67%
#
# Current iteration : 24
# Time taken by far : 4.0 seconds
# Current top member's network accuracy: 84.17%
#
# Current iteration : 25
# Time taken by far : 4.2 seconds
# Current top member's network accuracy: 90.83%
#
# Current iteration : 26
# Time taken by far : 4.3 seconds
# Current top member's network accuracy: 90.83%
#
# Current iteration : 27
# Time taken by far : 4.4 seconds
# Current top member's network accuracy: 90.83%
#
# Current iteration : 28
# Time taken by far : 4.6 seconds
# Current top member's network accuracy: 90.83%
#
# Current iteration : 29
# Time taken by far : 4.7 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 30
# Time taken by far : 4.9 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 31
# Time taken by far : 5.1 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 32
# Time taken by far : 5.2 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 33
# Time taken by far : 5.4 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 34
# Time taken by far : 5.5 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 35
# Time taken by far : 5.7 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 36
# Time taken by far : 5.9 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 37
# Time taken by far : 6.0 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 38
# Time taken by far : 6.2 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 39
# Time taken by far : 6.3 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 40
# Time taken by far : 6.5 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 41
# Time taken by far : 6.6 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 42
# Time taken by far : 6.8 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 43
# Time taken by far : 6.9 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 44
# Time taken by far : 7.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 45
# Time taken by far : 7.4 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 46
# Time taken by far : 7.6 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 47
# Time taken by far : 7.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 48
# Time taken by far : 7.9 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 49
# Time taken by far : 8.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 50
# Time taken by far : 8.3 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 51
# Time taken by far : 8.6 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 52
# Time taken by far : 8.8 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 53
# Time taken by far : 9.0 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 54
# Time taken by far : 9.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 55
# Time taken by far : 9.5 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 56
# Time taken by far : 9.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 57
# Time taken by far : 9.9 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 58
# Time taken by far : 10.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 59
# Time taken by far : 10.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 60
# Time taken by far : 10.4 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 61
# Time taken by far : 10.5 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 62
# Time taken by far : 10.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 63
# Time taken by far : 10.8 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 64
# Time taken by far : 11.0 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 65
# Time taken by far : 11.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 66
# Time taken by far : 11.3 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 67
# Time taken by far : 11.4 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 68
# Time taken by far : 11.6 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 69
# Time taken by far : 11.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 70
# Time taken by far : 11.9 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 71
# Time taken by far : 12.1 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 72
# Time taken by far : 12.2 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 73
# Time taken by far : 12.4 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 74
# Time taken by far : 12.6 seconds
# Current top member's network accuracy: 95.00%
#
# Current iteration : 75
# Time taken by far : 12.8 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 76
# Time taken by far : 12.9 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 77
# Time taken by far : 13.1 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 78
# Time taken by far : 13.2 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 79
# Time taken by far : 13.4 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 80
# Time taken by far : 13.5 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 81
# Time taken by far : 13.7 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 82
# Time taken by far : 13.9 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 83
# Time taken by far : 14.0 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 84
# Time taken by far : 14.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 85
# Time taken by far : 14.4 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 86
# Time taken by far : 14.6 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 87
# Time taken by far : 14.7 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 88
# Time taken by far : 14.9 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 89
# Time taken by far : 15.1 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 90
# Time taken by far : 15.3 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 91
# Time taken by far : 15.4 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 92
# Time taken by far : 15.6 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 93
# Time taken by far : 15.8 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 94
# Time taken by far : 16.0 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 95
# Time taken by far : 16.2 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 96
# Time taken by far : 16.4 seconds
# Current top member's network accuracy: 95.83%
#
# Current iteration : 97
# Time taken by far : 16.5 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 98
# Time taken by far : 16.7 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 99
# Time taken by far : 16.8 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 100
# Time taken by far : 17.1 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 101
# Time taken by far : 17.3 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 102
# Time taken by far : 17.5 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 103
# Time taken by far : 17.7 seconds
# Current top member's network accuracy: 96.67%
#
# Current iteration : 104
# Time taken by far : 17.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 105
# Time taken by far : 18.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 106
# Time taken by far : 18.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 107
# Time taken by far : 18.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 108
# Time taken by far : 18.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 109
# Time taken by far : 18.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 110
# Time taken by far : 18.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 111
# Time taken by far : 19.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 112
# Time taken by far : 19.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 113
# Time taken by far : 19.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 114
# Time taken by far : 19.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 115
# Time taken by far : 19.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 116
# Time taken by far : 19.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 117
# Time taken by far : 20.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 118
# Time taken by far : 20.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 119
# Time taken by far : 20.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 120
# Time taken by far : 20.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 121
# Time taken by far : 20.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 122
# Time taken by far : 21.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 123
# Time taken by far : 21.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 124
# Time taken by far : 21.4 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 125
# Time taken by far : 21.6 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 126
# Time taken by far : 21.8 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 127
# Time taken by far : 21.9 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 128
# Time taken by far : 22.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 129
# Time taken by far : 22.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 130
# Time taken by far : 22.4 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 131
# Time taken by far : 22.6 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 132
# Time taken by far : 22.8 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 133
# Time taken by far : 22.9 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 134
# Time taken by far : 23.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 135
# Time taken by far : 23.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 136
# Time taken by far : 23.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 137
# Time taken by far : 23.6 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 138
# Time taken by far : 23.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 139
# Time taken by far : 23.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 140
# Time taken by far : 24.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 141
# Time taken by far : 24.3 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 142
# Time taken by far : 24.6 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 143
# Time taken by far : 24.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 144
# Time taken by far : 25.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 145
# Time taken by far : 25.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 146
# Time taken by far : 25.4 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 147
# Time taken by far : 25.5 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 148
# Time taken by far : 25.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 149
# Time taken by far : 25.8 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 150
# Time taken by far : 26.0 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 151
# Time taken by far : 26.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 152
# Time taken by far : 26.5 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 153
# Time taken by far : 26.8 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 154
# Time taken by far : 27.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 155
# Time taken by far : 27.3 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 156
# Time taken by far : 27.5 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 157
# Time taken by far : 27.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 158
# Time taken by far : 27.8 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 159
# Time taken by far : 28.0 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 160
# Time taken by far : 28.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 161
# Time taken by far : 28.3 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 162
# Time taken by far : 28.5 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 163
# Time taken by far : 28.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 164
# Time taken by far : 28.9 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 165
# Time taken by far : 29.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 166
# Time taken by far : 29.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 167
# Time taken by far : 29.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 168
# Time taken by far : 29.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 169
# Time taken by far : 29.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 170
# Time taken by far : 30.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 171
# Time taken by far : 30.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 172
# Time taken by far : 30.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 173
# Time taken by far : 30.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 174
# Time taken by far : 30.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 175
# Time taken by far : 30.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 176
# Time taken by far : 31.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 177
# Time taken by far : 31.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 178
# Time taken by far : 31.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 179
# Time taken by far : 31.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 180
# Time taken by far : 31.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 181
# Time taken by far : 32.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 182
# Time taken by far : 32.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 183
# Time taken by far : 32.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 184
# Time taken by far : 32.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 185
# Time taken by far : 33.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 186
# Time taken by far : 33.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 187
# Time taken by far : 33.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 188
# Time taken by far : 33.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 189
# Time taken by far : 33.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 190
# Time taken by far : 33.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 191
# Time taken by far : 34.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 192
# Time taken by far : 34.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 193
# Time taken by far : 34.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 194
# Time taken by far : 34.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 195
# Time taken by far : 34.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 196
# Time taken by far : 35.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 197
# Time taken by far : 35.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 198
# Time taken by far : 35.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 199
# Time taken by far : 35.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 200
# Time taken by far : 35.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 201
# Time taken by far : 35.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 202
# Time taken by far : 36.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 203
# Time taken by far : 36.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 204
# Time taken by far : 36.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 205
# Time taken by far : 36.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 206
# Time taken by far : 36.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 207
# Time taken by far : 37.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 208
# Time taken by far : 37.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 209
# Time taken by far : 37.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 210
# Time taken by far : 37.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 211
# Time taken by far : 37.6 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 212
# Time taken by far : 37.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 213
# Time taken by far : 37.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 214
# Time taken by far : 38.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 215
# Time taken by far : 38.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 216
# Time taken by far : 38.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 217
# Time taken by far : 38.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 218
# Time taken by far : 38.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 219
# Time taken by far : 39.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 220
# Time taken by far : 39.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 221
# Time taken by far : 39.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 222
# Time taken by far : 39.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 223
# Time taken by far : 39.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 224
# Time taken by far : 40.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 225
# Time taken by far : 40.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 226
# Time taken by far : 40.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 227
# Time taken by far : 40.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 228
# Time taken by far : 40.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 229
# Time taken by far : 41.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 230
# Time taken by far : 41.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 231
# Time taken by far : 41.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 232
# Time taken by far : 41.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 233
# Time taken by far : 41.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 234
# Time taken by far : 42.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 235
# Time taken by far : 42.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 236
# Time taken by far : 42.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 237
# Time taken by far : 42.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 238
# Time taken by far : 42.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 239
# Time taken by far : 42.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 240
# Time taken by far : 43.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 241
# Time taken by far : 43.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 242
# Time taken by far : 43.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 243
# Time taken by far : 43.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 244
# Time taken by far : 43.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 245
# Time taken by far : 43.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 246
# Time taken by far : 44.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 247
# Time taken by far : 44.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 248
# Time taken by far : 44.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 249
# Time taken by far : 44.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 250
# Time taken by far : 44.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 251
# Time taken by far : 44.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 252
# Time taken by far : 44.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 253
# Time taken by far : 45.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 254
# Time taken by far : 45.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 255
# Time taken by far : 45.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 256
# Time taken by far : 45.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 257
# Time taken by far : 45.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 258
# Time taken by far : 45.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 259
# Time taken by far : 46.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 260
# Time taken by far : 46.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 261
# Time taken by far : 46.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 262
# Time taken by far : 46.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 263
# Time taken by far : 46.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 264
# Time taken by far : 46.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 265
# Time taken by far : 47.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 266
# Time taken by far : 47.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 267
# Time taken by far : 47.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 268
# Time taken by far : 47.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 269
# Time taken by far : 47.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 270
# Time taken by far : 48.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 271
# Time taken by far : 48.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 272
# Time taken by far : 48.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 273
# Time taken by far : 48.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 274
# Time taken by far : 48.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 275
# Time taken by far : 49.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 276
# Time taken by far : 49.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 277
# Time taken by far : 49.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 278
# Time taken by far : 49.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 279
# Time taken by far : 49.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 280
# Time taken by far : 49.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 281
# Time taken by far : 50.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 282
# Time taken by far : 50.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 283
# Time taken by far : 50.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 284
# Time taken by far : 50.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 285
# Time taken by far : 50.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 286
# Time taken by far : 50.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 287
# Time taken by far : 50.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 288
# Time taken by far : 51.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 289
# Time taken by far : 51.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 290
# Time taken by far : 51.4 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 291
# Time taken by far : 51.6 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 292
# Time taken by far : 51.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 293
# Time taken by far : 51.9 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 294
# Time taken by far : 52.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 295
# Time taken by far : 52.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 296
# Time taken by far : 52.4 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 297
# Time taken by far : 52.5 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 298
# Time taken by far : 52.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 299
# Time taken by far : 52.9 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 300
# Time taken by far : 53.0 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 301
# Time taken by far : 53.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 302
# Time taken by far : 53.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 303
# Time taken by far : 53.5 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 304
# Time taken by far : 53.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 305
# Time taken by far : 53.9 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 306
# Time taken by far : 54.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 307
# Time taken by far : 54.2 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 308
# Time taken by far : 54.4 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 309
# Time taken by far : 54.5 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 310
# Time taken by far : 54.7 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 311
# Time taken by far : 54.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 312
# Time taken by far : 55.1 seconds
# Current top member's network accuracy: 97.50%
#
# Current iteration : 313
# Time taken by far : 55.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 314
# Time taken by far : 55.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 315
# Time taken by far : 55.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 316
# Time taken by far : 55.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 317
# Time taken by far : 56.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 318
# Time taken by far : 56.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 319
# Time taken by far : 56.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 320
# Time taken by far : 56.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 321
# Time taken by far : 56.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 322
# Time taken by far : 56.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 323
# Time taken by far : 56.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 324
# Time taken by far : 57.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 325
# Time taken by far : 57.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 326
# Time taken by far : 57.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 327
# Time taken by far : 57.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 328
# Time taken by far : 57.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 329
# Time taken by far : 58.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 330
# Time taken by far : 58.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 331
# Time taken by far : 58.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 332
# Time taken by far : 58.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 333
# Time taken by far : 58.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 334
# Time taken by far : 58.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 335
# Time taken by far : 59.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 336
# Time taken by far : 59.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 337
# Time taken by far : 59.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 338
# Time taken by far : 59.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 339
# Time taken by far : 59.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 340
# Time taken by far : 59.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 341
# Time taken by far : 60.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 342
# Time taken by far : 60.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 343
# Time taken by far : 60.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 344
# Time taken by far : 60.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 345
# Time taken by far : 60.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 346
# Time taken by far : 60.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 347
# Time taken by far : 61.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 348
# Time taken by far : 61.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 349
# Time taken by far : 61.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 350
# Time taken by far : 61.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 351
# Time taken by far : 61.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 352
# Time taken by far : 61.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 353
# Time taken by far : 62.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 354
# Time taken by far : 62.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 355
# Time taken by far : 62.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 356
# Time taken by far : 62.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 357
# Time taken by far : 62.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 358
# Time taken by far : 62.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 359
# Time taken by far : 63.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 360
# Time taken by far : 63.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 361
# Time taken by far : 63.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 362
# Time taken by far : 63.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 363
# Time taken by far : 63.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 364
# Time taken by far : 64.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 365
# Time taken by far : 64.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 366
# Time taken by far : 64.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 367
# Time taken by far : 64.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 368
# Time taken by far : 65.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 369
# Time taken by far : 65.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 370
# Time taken by far : 65.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 371
# Time taken by far : 65.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 372
# Time taken by far : 65.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 373
# Time taken by far : 66.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 374
# Time taken by far : 66.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 375
# Time taken by far : 66.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 376
# Time taken by far : 66.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 377
# Time taken by far : 66.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 378
# Time taken by far : 67.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 379
# Time taken by far : 67.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 380
# Time taken by far : 67.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 381
# Time taken by far : 67.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 382
# Time taken by far : 68.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 383
# Time taken by far : 68.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 384
# Time taken by far : 68.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 385
# Time taken by far : 69.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 386
# Time taken by far : 69.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 387
# Time taken by far : 69.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 388
# Time taken by far : 70.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 389
# Time taken by far : 70.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 390
# Time taken by far : 70.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 391
# Time taken by far : 70.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 392
# Time taken by far : 70.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 393
# Time taken by far : 70.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 394
# Time taken by far : 71.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 395
# Time taken by far : 71.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 396
# Time taken by far : 71.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 397
# Time taken by far : 71.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 398
# Time taken by far : 71.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 399
# Time taken by far : 71.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 400
# Time taken by far : 71.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 401
# Time taken by far : 72.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 402
# Time taken by far : 72.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 403
# Time taken by far : 72.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 404
# Time taken by far : 72.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 405
# Time taken by far : 72.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 406
# Time taken by far : 72.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 407
# Time taken by far : 73.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 408
# Time taken by far : 73.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 409
# Time taken by far : 73.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 410
# Time taken by far : 73.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 411
# Time taken by far : 73.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 412
# Time taken by far : 73.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 413
# Time taken by far : 74.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 414
# Time taken by far : 74.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 415
# Time taken by far : 74.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 416
# Time taken by far : 74.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 417
# Time taken by far : 74.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 418
# Time taken by far : 74.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 419
# Time taken by far : 75.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 420
# Time taken by far : 75.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 421
# Time taken by far : 75.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 422
# Time taken by far : 75.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 423
# Time taken by far : 75.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 424
# Time taken by far : 75.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 425
# Time taken by far : 75.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 426
# Time taken by far : 76.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 427
# Time taken by far : 76.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 428
# Time taken by far : 76.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 429
# Time taken by far : 76.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 430
# Time taken by far : 76.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 431
# Time taken by far : 77.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 432
# Time taken by far : 77.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 433
# Time taken by far : 77.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 434
# Time taken by far : 77.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 435
# Time taken by far : 77.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 436
# Time taken by far : 77.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 437
# Time taken by far : 78.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 438
# Time taken by far : 78.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 439
# Time taken by far : 78.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 440
# Time taken by far : 78.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 441
# Time taken by far : 78.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 442
# Time taken by far : 78.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 443
# Time taken by far : 78.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 444
# Time taken by far : 79.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 445
# Time taken by far : 79.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 446
# Time taken by far : 79.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 447
# Time taken by far : 79.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 448
# Time taken by far : 79.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 449
# Time taken by far : 79.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 450
# Time taken by far : 79.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 451
# Time taken by far : 80.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 452
# Time taken by far : 80.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 453
# Time taken by far : 80.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 454
# Time taken by far : 80.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 455
# Time taken by far : 80.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 456
# Time taken by far : 80.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 457
# Time taken by far : 80.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 458
# Time taken by far : 81.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 459
# Time taken by far : 81.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 460
# Time taken by far : 81.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 461
# Time taken by far : 81.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 462
# Time taken by far : 81.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 463
# Time taken by far : 81.9 seconds
# ...
#
# Current iteration : 849
# Time taken by far : 149.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 850
# Time taken by far : 149.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 851
# Time taken by far : 149.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 852
# Time taken by far : 149.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 853
# Time taken by far : 150.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 854
# Time taken by far : 150.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 855
# Time taken by far : 150.4 seconds
# Current top member's network accuracy: 99.17%
#
# Current iteration : 856
# Time taken by far : 150.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 857
# Time taken by far : 150.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 858
# Time taken by far : 151.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 859
# Time taken by far : 151.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 860
# Time taken by far : 151.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 861
# Time taken by far : 151.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 862
# Time taken by far : 151.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 863
# Time taken by far : 151.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 864
# Time taken by far : 152.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 865
# Time taken by far : 152.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 866
# Time taken by far : 152.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 867
# Time taken by far : 152.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 868
# Time taken by far : 152.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 869
# Time taken by far : 152.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 870
# Time taken by far : 153.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 871
# Time taken by far : 153.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 872
# Time taken by far : 153.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 873
# Time taken by far : 153.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 874
# Time taken by far : 153.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 875
# Time taken by far : 153.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 876
# Time taken by far : 153.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 877
# Time taken by far : 154.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 878
# Time taken by far : 154.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 879
# Time taken by far : 154.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 880
# Time taken by far : 154.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 881
# Time taken by far : 155.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 882
# Time taken by far : 155.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 883
# Time taken by far : 155.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 884
# Time taken by far : 155.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 885
# Time taken by far : 155.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 886
# Time taken by far : 155.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 887
# Time taken by far : 156.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 888
# Time taken by far : 156.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 889
# Time taken by far : 156.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 890
# Time taken by far : 156.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 891
# Time taken by far : 156.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 892
# Time taken by far : 156.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 893
# Time taken by far : 157.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 894
# Time taken by far : 157.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 895
# Time taken by far : 157.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 896
# Time taken by far : 157.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 897
# Time taken by far : 157.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 898
# Time taken by far : 157.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 899
# Time taken by far : 158.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 900
# Time taken by far : 158.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 901
# Time taken by far : 158.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 902
# Time taken by far : 158.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 903
# Time taken by far : 158.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 904
# Time taken by far : 159.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 905
# Time taken by far : 159.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 906
# Time taken by far : 159.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 907
# Time taken by far : 159.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 908
# Time taken by far : 159.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 909
# Time taken by far : 159.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 910
# Time taken by far : 160.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 911
# Time taken by far : 160.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 912
# Time taken by far : 160.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 913
# Time taken by far : 160.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 914
# Time taken by far : 160.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 915
# Time taken by far : 161.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 916
# Time taken by far : 161.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 917
# Time taken by far : 161.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 918
# Time taken by far : 161.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 919
# Time taken by far : 161.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 920
# Time taken by far : 161.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 921
# Time taken by far : 162.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 922
# Time taken by far : 162.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 923
# Time taken by far : 162.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 924
# Time taken by far : 162.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 925
# Time taken by far : 162.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 926
# Time taken by far : 162.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 927
# Time taken by far : 162.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 928
# Time taken by far : 163.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 929
# Time taken by far : 163.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 930
# Time taken by far : 163.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 931
# Time taken by far : 163.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 932
# Time taken by far : 163.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 933
# Time taken by far : 164.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 934
# Time taken by far : 164.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 935
# Time taken by far : 164.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 936
# Time taken by far : 164.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 937
# Time taken by far : 164.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 938
# Time taken by far : 165.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 939
# Time taken by far : 165.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 940
# Time taken by far : 165.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 941
# Time taken by far : 165.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 942
# Time taken by far : 165.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 943
# Time taken by far : 165.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 944
# Time taken by far : 166.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 945
# Time taken by far : 166.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 946
# Time taken by far : 166.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 947
# Time taken by far : 166.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 948
# Time taken by far : 166.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 949
# Time taken by far : 166.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 950
# Time taken by far : 167.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 951
# Time taken by far : 167.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 952
# Time taken by far : 167.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 953
# Time taken by far : 167.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 954
# Time taken by far : 167.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 955
# Time taken by far : 167.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 956
# Time taken by far : 168.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 957
# Time taken by far : 168.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 958
# Time taken by far : 168.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 959
# Time taken by far : 168.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 960
# Time taken by far : 168.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 961
# Time taken by far : 168.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 962
# Time taken by far : 169.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 963
# Time taken by far : 169.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 964
# Time taken by far : 169.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 965
# Time taken by far : 169.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 966
# Time taken by far : 169.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 967
# Time taken by far : 169.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 968
# Time taken by far : 170.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 969
# Time taken by far : 170.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 970
# Time taken by far : 170.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 971
# Time taken by far : 170.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 972
# Time taken by far : 170.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 973
# Time taken by far : 170.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 974
# Time taken by far : 170.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 975
# Time taken by far : 171.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 976
# Time taken by far : 171.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 977
# Time taken by far : 171.4 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 978
# Time taken by far : 171.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 979
# Time taken by far : 171.7 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 980
# Time taken by far : 171.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 981
# Time taken by far : 172.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 982
# Time taken by far : 172.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 983
# Time taken by far : 172.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 984
# Time taken by far : 172.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 985
# Time taken by far : 172.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 986
# Time taken by far : 172.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 987
# Time taken by far : 173.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 988
# Time taken by far : 173.2 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 989
# Time taken by far : 173.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 990
# Time taken by far : 173.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 991
# Time taken by far : 173.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 992
# Time taken by far : 173.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 993
# Time taken by far : 174.0 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 994
# Time taken by far : 174.1 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 995
# Time taken by far : 174.3 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 996
# Time taken by far : 174.5 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 997
# Time taken by far : 174.6 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 998
# Time taken by far : 174.8 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 999
# Time taken by far : 174.9 seconds
# Current top member's network accuracy: 98.33%
#
# Current iteration : 1000
# Time taken by far : 175.1 seconds
# Current top member's network accuracy: 98.33%

# %%
saveReport(accuracy_history)
