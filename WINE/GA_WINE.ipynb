# %%
# https://www.knowledgehut.com/blog/data-science/types-of-classification-in-ml
from sklearn.datasets import make_blobs 
from collections import Counter 
from numpy import where 
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import pickle

def load_datasets(datasets_name="wine"):
    if datasets_name == "iris":
        dataset = datasets.load_iris()
    elif datasets_name == "wine":
        dataset = datasets.load_wine()

    X = dataset.data
    y = dataset.target

    y_ = y.reshape(-1, 1) # Convert data to a single column

    # One Hot encode the class labels
    encoder = OneHotEncoder(sparse=False)
    y = encoder.fit_transform(y_)

    # Split the data for training and testing
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    return x_train, x_test, y_train, y_test

def saveReport(accuracy_history):
    data = {
        "accuracy_history": accuracy_history
    }
    pickle.dump(data, open("./GA_report.pkl", "wb"))

x_train, x_test, y_train, y_test = load_datasets()

# %%
import random
import numpy as np
import pandas as pd
import copy
import time
from numpy import exp
from sklearn.preprocessing import OneHotEncoder

random.seed(42)
np.random.seed(42)

class Network(object):

    def __init__(self, sizes):
        
        '''The list ``sizes`` contains the number of neurons in the
        respective layers of the network.  For example, if the list
        was [2, 3, 1] then it would be a three-layer network, with the
        first layer containing 2 neurons, the second layer 3 neurons,
        and the third layer 1 neuron.  The biases and weights for the
        network are initialized randomly, using a Gaussian
        distribution with mean 0, and variance 1.  Note that the first
        layer is assumed to be an input layer, and by convention we
        won't set any biases for those neurons, since biases are only
        ever used in computing the outputs from later layers.'''

        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
        
        # helper variables
        self.bias_nitem = sum(sizes[1:])
        self.weight_nitem = sum([self.weights[i].size for i in range(self.num_layers-2)])

    def feedforward(self, a):
        '''Return the output of the network if ``a`` is input.'''
        for b, w in zip(self.biases, self.weights):
            a = self.sigmoid(np.dot(w,a)+b)
            # a = np.dot(w,a)+b
        # a = self.softmax(a)
        return a

    # Actifation Functions
    def softmax(self, z):
        e = exp(z)
        e_sum = e.sum()
        if e_sum == 0:
            e_sum = 1
        return e / e_sum

    def sigmoid(self, z):
        '''The sigmoid function.'''
        return 1.0/(1.0+np.exp(-z))

    def relu(self, z):
        def relu_func(x):
            return x if x > 0 else 0
        return np.array(list(map(relu_func, z)))

    def score(self, X, y):

        '''
        @X = data to test
        @y = data-label to test
        @returns = score of network prediction (less is better)
        @ref: https://stats.stackexchange.com/questions/154879/a-list-of-cost-functions-used-in-neural-networks-alongside-applications
        '''

        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            score = np.sum(np.power(predicted-actual,2))
            # print("Accuracy Argmax:", np.argmax(predicted), np.argmax(actual), "Score:",score)
            # txt ="[ "
            # for pred in predicted:
            #     txt += "{}, ".format(pred)
            # print(txt, "]", sum(predicted))
            total_score += score  # mean-squared error
        # total_score /= X.shape[0] 
        # print("Total Score:", total_score)
        return total_score

    def accuracy(self, X, y):

        '''
        @X = data to test
        @y = data-label to test
        @returns = accuracy (%) (more is better)
        '''

        accuracy = 0
        for i in range(X.shape[0]):
            output = self.feedforward(X[i].reshape(-1,1))
            accuracy += int(np.argmax(output) == np.argmax(y[i]))
        return (accuracy / X.shape[0]) * 100

    def __str__(self):
        s = "\nBias:\n\n" + str(self.biases)
        s += "\nWeights:\n\n" + str(self.weights)
        s += "\n\n"
        return s

class NNGeneticAlgo:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, retain_rate, X, y):

        '''
        n_pops   = How much population do our GA need to create
        net_size = Size of neural network for population members
        mutation_rate = probability of mutating all bias & weight inside our network
        crossover_rate = probability of cross-overing all bias & weight inside out network
        retain_rate = How many to retain our population for the best ones
        X = our data to test accuracy
        y = our data-label to test accuracy
        '''

        self.n_pops = n_pops
        self.net_size = net_size
        self.nets = [Network(self.net_size) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.retain_rate = retain_rate
        self.X = X[:]
        self.y = y[:]
    
    def get_random_point(self, type):

        '''
        @type = either 'weight' or 'bias'
        @returns tuple (layer_index, point_index)
            note: if type is set to 'weight', point_index will return (row_index, col_index)
        '''

        nn = self.nets[0]
        layer_index, point_index = random.randint(0, nn.num_layers-2), 0
        if type == 'weight':
            row = random.randint(0,nn.weights[layer_index].shape[0]-1)
            col = random.randint(0,nn.weights[layer_index].shape[1]-1)
            point_index = (row, col)
        elif type == 'bias':
            point_index = random.randint(0,nn.biases[layer_index].size-1)
        return (layer_index, point_index)

    def get_all_scores(self):
        return [net.score(self.X, self.y) for net in self.nets]

    def get_all_accuracy(self):
        return [net.accuracy(self.X, self.y) for net in self.nets]

    def crossover(self, father, mother):

        '''
        @father = neural-net object representing father
        @mother = neural-net object representing mother
        @returns = new child based on father/mother genetic information
        '''

        # make a copy of father 'genetic' weights & biases information
        nn = copy.deepcopy(father)

        # cross-over bias
        for _ in range(self.nets[0].bias_nitem):
            # get some random points
            layer, point = self.get_random_point('bias')
            # replace genetic (bias) with mother's value
            if random.uniform(0,1) < self.crossover_rate:
                nn.biases[layer][point] = mother.biases[layer][point]

        # cross-over weight
        for _ in range(self.nets[0].weight_nitem):
            # get some random points
            layer, point = self.get_random_point('weight')
            # replace genetic (weight) with mother's value
            if random.uniform(0,1) < self.crossover_rate:
                nn.weights[layer][point] = mother.weights[layer][point]
        
        return nn
        
    def mutation(self, child):

        '''
        @child_index = neural-net object to mutate its internal weights & biases value
        @returns = new mutated neural-net
        '''

        nn = copy.deepcopy(child)

        # mutate bias
        for _ in range(self.nets[0].bias_nitem):
            # get some random points
            layer, point = self.get_random_point('bias')
            # add some random value between -0.5 and 0.5
            if random.uniform(0,1) < self.mutation_rate:
                nn.biases[layer][point] += random.uniform(-0.5, 0.5)

        # mutate weight
        for _ in range(self.nets[0].weight_nitem):
            # get some random points
            layer, point = self.get_random_point('weight')
            # add some random value between -0.5 and 0.5
            if random.uniform(0,1) < self.mutation_rate:
                nn.weights[layer][point[0], point[1]] += random.uniform(-0.5, 0.5)

        return nn

    def evolve(self):

        # calculate score for each population of neural-net
        score_list = list(zip(self.nets, self.get_all_scores()))

        # sort the network using its score
        score_list.sort(key=lambda x: x[1])
        # print("Sorted Score List")
        # print("Sorted Score:", [obj[1] for obj in score_list])
        # print()
        # exclude score as it is not needed anymore
        score_list = [obj[0] for obj in score_list]

        # keep only the best one
        retain_num = int(self.n_pops*self.retain_rate)
        score_list_top = score_list[:retain_num]

        # return some non-best ones
        retain_non_best = int((self.n_pops-retain_num) * self.retain_rate)
        for _ in range(random.randint(0, retain_non_best)):
            score_list_top.append(random.choice(score_list[retain_num:]))

        # breed new childs if current population number less than what we want
        while len(score_list_top) < self.n_pops:

            father = random.choice(score_list_top[:retain_num + retain_non_best])
            mother = random.choice(score_list_top[:retain_num + retain_non_best])

            if father != mother:
                new_child = self.crossover(father, mother)
                new_child = self.mutation(new_child)
                score_list_top.append(new_child)
        
        # copy our new population to current object
        self.nets = score_list_top

# %%
X = x_train
y = y_train

print(X.shape)
print(y.shape)

# parameters
N_POPS = 30
NET_SIZE = [X[0].shape[0],20,y[0].shape[0]] 
MUTATION_RATE = 0.2
CROSSOVER_RATE = 0.4
RETAIN_RATE = 0.4

EPOCH = 1000

# start our neural-net & optimize it using genetic algorithm
nnga = NNGeneticAlgo(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, RETAIN_RATE, X, y)

start_time = time.time()

# run for n iterations
accuracy_history = []
# for i in range(1000):
global_prev_best_accuracy = 0
max_count_after_best = 100
count_after_best = 0
for i in range(EPOCH):

    # accuracy = 
    best_current_accuracy = max(nnga.get_all_accuracy())
    if i % 1 == 0:
        print("Current iteration : {}".format(i+1))
        print("Time taken by far : %.1f seconds" % (time.time() - start_time))
        print("Current top member's network accuracy: %.2f%%\n" %best_current_accuracy)
        # print(nnga.get_all_accuracy())
        
    accuracy_history.append(best_current_accuracy)
    # if global_prev_best_accuracy < best_current_accuracy:
    #     global_prev_best_accuracy = best_current_accuracy
    #     count_after_best = 0
    # else:
    #     count_after_best += 1
    
    # if count_after_best > max_count_after_best:
    #     print("Early Stopped after", count_after_best, "without improvemnet from: ", global_prev_best_accuracy, "Current was:", best_current_accuracy)
    #     break

    # evolve the population
    nnga.evolve()

import numpy as np
import matplotlib.pyplot as plt
plt.plot(accuracy_history)
plt.show()


saveReport(accuracy_history)
# Out:
# (142, 13)
# (142, 3)
# Current iteration : 1
# Time taken by far : 0.1 seconds
# Current top member's network accuracy: 49.30%
# C:\Users\johan\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:54: RuntimeWarning: overflow encountered in exp
# Sorted Score List
# Sorted Score: [105.3549979333823, 107.38715854769785, 111.82721449039794, 111.86396111434581, 120.50599134965896, 124.74436700943065, 126.19085511845678, 132.99669001646097, 136.97391271383344, 141.0645526447519, 144.60638386901852, 145.1143128126038, 145.5248078040376, 147.40584842470312, 148.53268370870612, 148.94309000681525, 150.681516840099, 151.41501706552123, 153.1411864090921, 155.20179015569911, 161.87569951873934, 162.83094988927422, 163.2962510038729, 167.10824570012687, 168.5535130896771, 176.3652192977669, 198.45067144908234, 216.53529480346796, 222.43021224509084, 231.8941584745828]
#
# Current iteration : 2
# Time taken by far : 0.5 seconds
# Current top member's network accuracy: 40.14%
#
# Sorted Score List
# Sorted Score: [95.07040852736313, 100.31632860129906, 105.3549979333823, 107.38715854769785, 110.5660340868743, 111.82721449039794, 111.86396111434581, 115.37672922091615, 117.8500304131087, 120.43376531543018, 120.50599134965896, 124.74436700943065, 125.49265731584498, 126.19085511845678, 127.54037060813586, 132.99669001646097, 134.3861236451, 135.14076301617538, 135.25825729222066, 136.97391271383344, 141.0645526447519, 142.3404013847313, 144.60638386901852, 145.1143128126038, 145.5248078040376, 188.9227264144472, 192.42182484611365, 194.65573352393332, 221.08668334729586, 225.4133595640468]
#
# Current iteration : 3
# Time taken by far : 0.8 seconds
# Current top member's network accuracy: 40.14%
#
# Sorted Score List
# Sorted Score: [95.07040852736313, 99.90419627960875, 100.31632860129906, 105.3549979333823, 107.38715854769785, 110.5660340868743, 111.82721449039794, 111.86396111434581, 115.37672922091615, 117.8500304131087, 120.43376531543018, 120.50599134965896, 124.74436700943065, 125.34762247289129, 127.54037060813586, 127.73094398191881, 130.21029500049517, 133.8940485823187, 135.27581971737175, 140.25070673017578, 144.60638386901852, 151.57594260783787, 151.88247080566236, 152.86054622459238, 153.74149110705753, 154.73316132623097, 166.11976242603933, 189.42157027497427, 193.62992080833618, 215.58988308541436]
#
# Current iteration : 4
# Time taken by far : 1.1 seconds
# Current top member's network accuracy: 52.11%
#
# Sorted Score List
# Sorted Score: [91.28385126321383, 95.07040852736313, 99.90419627960875, 100.31632860129906, 105.3549979333823, 107.07471179184971, 107.38715854769785, 107.98335973812605, 110.5660340868743, 110.88537068602692, 111.82721449039794, 111.86396111434581, 115.37672922091615, 117.8500304131087, 120.16155601768041, 120.43376531543018, 120.50599134965896, 122.71805020521421, 125.90639025129562, 129.6924775444454, 133.2721853572272, 137.17222668572265, 144.62627490216184, 166.61354817999216, 177.37017987479862, 178.2751397659708, 187.8433691596483, 209.69040873352188, 221.77723830108215, 250.71314821512894]
#
# Current iteration : 5
# Time taken by far : 1.4 seconds
# Current top member's network accuracy: 52.11%
#
# Sorted Score List
# Sorted Score: [91.28385126321383, 95.07040852736313, 97.00787781615901, 99.90419627960875, 100.31632860129906, 104.9697114607615, 105.3549979333823, 107.07471179184971, 107.38715854769785, 107.98335973812605, 108.94580663345596, 109.7580176888383, 110.5660340868743, 110.88537068602692, 111.82721449039794, 111.86396111434581, 116.85379244539982, 121.64777143283071, 125.24753321322977, 126.15185335980307, 136.00841019639537, 144.78237972446976, 145.03109008649767, 158.86285433713653, 177.37017987479862, 187.8433691596483, 199.82812386335019, 209.69040873352188, 209.69040873352188, 250.71314821512894]
#
# Current iteration : 6
# Time taken by far : 1.7 seconds
# Current top member's network accuracy: 55.63%
#
# Sorted Score List
# Sorted Score: [91.28385126321383, 95.07040852736313, 97.00787781615901, 99.90419627960875, 100.31632860129906, 103.99267104452382, 104.82908541035583, 104.9697114607615, 105.3549979333823, 107.07471179184971, 107.38715854769785, 107.50099301124138, 107.98335973812605, 107.99181562628185, 108.94580663345596, 109.7580176888383, 109.94265045586472, 116.8046637616337, 124.75299649204626, 125.24753321322977, 126.7073139014147, 130.52480830798496, 131.49379307998493, 136.00841019639537, 140.97996881786955, 152.11636880123442, 153.45052186692445, 200.0394777416847, 209.69040873352188, 250.71314821512894]
#
# Current iteration : 7
# Time taken by far : 2.0 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 89.4430737388695, 91.28385126321383, 95.07040852736313, 97.00787781615901, 99.90419627960875, 100.31632860129906, 103.70053253263906, 103.99267104452382, 104.82908541035583, 104.9697114607615, 105.3549979333823, 107.07471179184971, 107.38715854769785, 107.50099301124138, 107.98335973812605, 107.98335973812605, 109.94265045586472, 113.65781181203768, 115.3668825125993, 116.25975509855934, 125.24753321322977, 125.78227719668409, 131.29574192644, 131.8117623336124, 132.91620033267228, 136.00841019639537, 136.00841019639537, 148.21910518392144, 148.488140187188]
#
# Current iteration : 8
# Time taken by far : 2.3 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 89.4430737388695, 91.28385126321383, 95.07040852736313, 97.00787781615901, 97.3054106763772, 99.48247925067848, 99.90419627960875, 100.31632860129906, 102.81686071456508, 102.96968565208977, 103.21025973125099, 103.70053253263906, 103.99267104452382, 104.82908541035583, 104.9697114607615, 105.3549979333823, 107.07471179184971, 107.07471179184971, 107.98335973812605, 107.98335973812605, 107.98335973812605, 112.16856561021865, 115.3668825125993, 116.25975509855934, 123.72481950934392, 128.93723260870019, 133.24522886051307, 134.01557381709574, 164.181742541114]
#
# Current iteration : 9
# Time taken by far : 2.6 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 89.4430737388695, 91.28385126321383, 95.07040852736313, 97.00787781615901, 97.07477948301941, 97.3054106763772, 97.44260314089952, 99.48247925067848, 99.90419627960875, 100.31632860129906, 102.25113418417311, 102.42207009732972, 102.5762788541326, 102.81686071456508, 102.96968565208977, 103.21025973125099, 103.58601435548505, 107.07471179184971, 107.69009446174339, 107.98335973812605, 107.98335973812605, 111.29613757101505, 113.09453762902099, 119.79182222999833, 122.47910331866028, 123.72481950934392, 128.44412759311209, 156.44419363509573, 208.27259905199298]
#
# Current iteration : 10
# Time taken by far : 3.0 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 89.4430737388695, 91.28385126321383, 95.07040852736313, 97.00787781615901, 97.07477948301941, 97.3054106763772, 97.44260314089952, 99.48247925067848, 99.90419627960875, 100.31632860129906, 102.25113418417311, 102.5762788541326, 102.5762788541326, 102.5762788541326, 102.96968565208977, 102.96968565208977, 110.33084224592842, 111.95599780150219, 114.66391900077517, 116.03259861421341, 124.08299916306956, 124.3625811789851, 125.56518759142077, 128.44412759311209, 128.90406549409298, 153.15307540118187, 162.7936814160289, 191.42851852662787, 208.27259905199298]
#
# Current iteration : 11
# Time taken by far : 3.2 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 89.4430737388695, 91.28385126321383, 95.07040852736313, 97.00787781615901, 97.07477948301941, 97.3054106763772, 97.44260314089952, 99.48247925067848, 99.69738524467623, 99.90419627960875, 100.14328813632031, 100.31632860129906, 102.25113418417311, 107.05915251343734, 109.71681058197258, 110.33084224592842, 110.33084224592842, 111.95599780150219, 116.38298710316104, 128.44412759311209, 128.44412759311209, 128.85777321125968, 135.36949418883214, 135.3743585418935, 137.38425899275796, 150.579376792072, 153.12198954891153, 162.23124276484208, 162.7936814160289]
#
# Current iteration : 12
# Time taken by far : 3.5 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 91.28385126321383, 95.07040852736313, 95.90480886397182, 97.00787781615901, 97.07477948301941, 97.3054106763772, 97.44260314089952, 99.48247925067848, 99.69738524467623, 99.90419627960875, 100.14328813632031, 100.31632860129906, 100.58683615538925, 101.0856890352878, 102.25113418417311, 104.6820248469285, 105.28786045754737, 105.48455338547106, 106.58860372960318, 107.21477987889705, 123.59589213809623, 123.96703801020448, 127.74743794807958, 130.41350348802436, 137.43192509272532, 156.28603796307215, 202.28420920082849]
#
# Current iteration : 13
# Time taken by far : 3.7 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 91.28385126321383, 93.04257424295116, 95.07040852736313, 95.90480886397182, 97.00787781615901, 97.07477948301941, 97.3054106763772, 97.44260314089952, 99.48247925067848, 99.69738524467623, 101.0856890352878, 107.01030049764974, 107.97537428173001, 108.75411078407797, 112.20841214937161, 112.89626128363172, 114.7254590285327, 116.78693756008428, 117.1701735165938, 123.96703801020448, 124.59155927368288, 132.9761107482802, 133.9064695377791, 141.23742294268328, 161.94329190658266, 178.35712715999622, 184.50579522858396]
#
# Current iteration : 14
# Time taken by far : 4.0 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 91.28385126321383, 93.04257424295116, 95.07040852736313, 95.90480886397182, 97.00787781615901, 97.07477948301941, 97.3054106763772, 97.44260314089952, 98.77852328408487, 99.48247925067848, 101.0856890352878, 106.50810525836381, 107.97537428173001, 107.97537428173001, 111.57140135727374, 111.61304303918607, 113.65700622017704, 116.08823450857032, 116.65919768328482, 123.96703801020448, 128.63568667203998, 128.8233854486259, 150.78831988196444, 152.03609107259382, 164.12965031659454, 174.92880432680394, 178.35712715999622]
#
# Current iteration : 15
# Time taken by far : 4.2 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 91.28385126321383, 93.04257424295116, 95.07040852736313, 95.90480886397182, 96.59929708548701, 97.00787781615901, 97.07477948301941, 97.3054106763772, 97.44260314089952, 97.74869703541123, 98.77852328408487, 99.50005677861435, 102.25952042841148, 105.70552269993738, 105.73835355558788, 110.77472810495483, 110.93963051391648, 115.74201918964849, 116.84628792297542, 118.68510318955045, 128.63568667203998, 133.1396313292683, 138.10700940612745, 139.62046039815817, 155.66714460178724, 158.6035730063574, 164.53488975484282]
#
# Current iteration : 16
# Time taken by far : 4.6 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 91.28385126321383, 93.04257424295116, 95.07040852736313, 95.90480886397182, 96.59929708548701, 97.00787781615901, 97.07477948301941, 97.3054106763772, 97.44260314089952, 104.11797685218649, 104.3079727855379, 111.08102078932795, 111.19907420527294, 112.31902202025908, 113.89799948857573, 117.01472557729839, 119.40991647641982, 119.73220578425727, 120.5589351093923, 135.70017803012297, 138.5456751223621, 141.57747128948702, 142.31638852720133, 143.70432477768722, 151.47851763011198, 155.5585012465406, 172.53783071569558]
#
# Current iteration : 17
# Time taken by far : 4.8 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.28385126321383, 93.04257424295116, 95.07040852736313, 95.52634717578991, 95.90480886397182, 96.59929708548701, 97.00787781615901, 97.07477948301941, 97.3054106763772, 97.44260314089952, 100.51152504103611, 107.89856664506573, 112.58451009437191, 114.95446358228855, 115.78945024059844, 119.40991647641982, 119.52150365083372, 120.5589351093923, 120.56028606477277, 126.01570659973949, 129.03388317614613, 141.2634608723296, 143.09566548989253, 143.70432477768722, 162.42628175146524, 170.59008830842689]
#
# Current iteration : 18
# Time taken by far : 5.1 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.28385126321383, 93.04257424295116, 95.07040852736313, 95.52634717578991, 95.90480886397182, 96.59929708548701, 97.00787781615901, 97.07477948301941, 97.3054106763772, 103.23442655309817, 105.08772705492231, 107.89856664506573, 110.11401256557708, 114.06355088284134, 119.52150365083372, 120.07711284536488, 122.4268494303447, 123.69791288887401, 124.26602246795912, 133.7017031146569, 141.2634608723296, 149.00951186934998, 152.33346699988607, 162.35734820488264, 162.42628175146524, 175.32876362958865]
#
# Current iteration : 19
# Time taken by far : 5.3 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.28385126321383, 93.04257424295116, 95.07040852736313, 95.52634717578991, 95.90480886397182, 96.59929708548701, 97.00787781615901, 97.07477948301941, 105.15455428209047, 109.55340673433061, 111.82437641331228, 119.3897344886257, 126.33154804340869, 126.35560961825745, 127.69436894761553, 149.00951186934998, 149.84216531211445, 150.70736856785118, 152.33346699988607, 158.3445487761197, 162.42628175146524, 162.42628175146524, 163.09185669937688, 187.30479957931001, 197.2153017042517, 204.00039210603046]
#
# Current iteration : 20
# Time taken by far : 5.6 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.28385126321383, 92.96406798204066, 93.04257424295116, 95.07040852736313, 95.52634717578991, 95.90480886397182, 96.59929708548701, 97.00787781615901, 97.07477948301941, 103.84385393629344, 108.25632993173701, 114.76153591779409, 119.7621997087403, 119.92896080197724, 126.33154804340869, 128.07542833038235, 129.90330946132337, 135.02497149851885, 140.33308966201753, 140.76659005924884, 142.3896230656459, 158.4572879393961, 158.60619942934514, 161.16808808296784, 162.42628175146524, 197.2153017042517]
#
# Current iteration : 21
# Time taken by far : 5.8 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.28385126321383, 92.96406798204066, 93.04257424295116, 95.07040852736313, 95.52634717578991, 95.90480886397182, 96.59929708548701, 97.00787781615901, 103.20104717045099, 109.62299616979065, 109.64484336373243, 110.41042582882586, 110.82517672240161, 111.50015597421921, 113.63454482891981, 116.00743486254501, 118.41254089537543, 118.90243175409827, 124.72253245809756, 129.32449812468204, 133.61080873086084, 138.31841659995047, 150.47238270147778, 151.83693795468932, 152.05022391341947, 158.60619942934514]
#
# Current iteration : 22
# Time taken by far : 6.1 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 84.08454004525744, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.28385126321383, 92.60305825860578, 92.96406798204066, 93.04257424295116, 95.07040852736313, 95.52634717578991, 95.90480886397182, 96.59929708548701, 97.00787781615901, 102.02345940854511, 107.06360041847802, 112.26927932845341, 117.91265602316629, 119.18074299372427, 119.39533370860134, 126.49122680771234, 129.3849138905642, 136.84231467382358, 143.48415095064382, 144.88692629064624, 158.74761968744792, 158.9518098664899, 159.12628294661502, 160.71023348069758, 161.28543276691707]
#
# Current iteration : 23
# Time taken by far : 6.3 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 84.08454004525744, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.60305825860578, 92.96406798204066, 93.04257424295116, 95.07040852736313, 95.52634717578991, 95.90480886397182, 96.59929708548701, 97.00787781615901, 97.00787781615901, 106.15300046562285, 107.06360041847802, 108.42099470816247, 113.27610320708297, 115.39005037872681, 116.23386098506703, 116.70729432820522, 119.18074299372427, 120.34940352938916, 123.29146223335547, 129.3849138905642, 158.9518098664899, 164.9725194006386, 198.97014838522261]
#
# Current iteration : 24
# Time taken by far : 6.6 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 84.08454004525744, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.60305825860578, 92.96406798204066, 93.04257424295116, 95.07040852736313, 95.52634717578991, 96.08885263218754, 100.58046025460402, 109.5841820836618, 111.65669332024812, 111.98402621543116, 115.64146952744146, 116.23386098506703, 120.1448208634381, 120.38206095002806, 126.14507901307366, 127.93175591906966, 129.70275603898975, 134.84875247496478, 137.60134887516807, 140.0121492891814, 152.27375804542876, 169.3531378469128, 169.75823461054475]
#
# Current iteration : 25
# Time taken by far : 6.8 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 84.08454004525744, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.60305825860578, 92.96406798204066, 93.04257424295116, 95.07040852736313, 95.52634717578991, 106.44125928028718, 115.64146952744146, 116.23386098506703, 116.31593406730947, 120.52957585430228, 126.14507901307366, 129.91466641847703, 131.16690654464446, 132.99469390667855, 133.38685757261987, 134.84875247496478, 137.60134887516807, 140.0121492891814, 140.0121492891814, 146.33633092009785, 157.9325790645305, 177.2759067214922, 188.5344301732933]
#
# Current iteration : 26
# Time taken by far : 7.1 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 84.08454004525744, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.60305825860578, 92.96406798204066, 93.04257424295116, 93.42330992183737, 95.07040852736313, 95.52634717578991, 97.84071450701732, 99.07065500684233, 104.51111552451832, 106.15339948703689, 109.52066549350583, 111.15121172274988, 120.52957585430228, 120.52957585430228, 121.30405989857088, 125.70378775785443, 133.38685757261987, 137.60134887516807, 140.0121492891814, 141.1112921968165, 148.18904540919905, 156.67909109572958, 161.39019712159347]
#
# Current iteration : 27
# Time taken by far : 7.3 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 84.08454004525744, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.60305825860578, 92.96406798204066, 93.04257424295116, 93.42330992183737, 95.07040852736313, 101.85539744129495, 104.51111552451832, 104.93592506690848, 106.44978521163556, 109.52066549350583, 111.15121172274988, 113.8564173019516, 115.73396413229902, 116.68902951897644, 120.52957585430228, 127.32909160272156, 130.37156341436713, 135.24008577830136, 140.0121492891814, 148.18904540919905, 158.00137880057707, 161.39019712159347, 164.16970824322752]
#
# Current iteration : 28
# Time taken by far : 7.6 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 84.04135476328173, 84.08454004525744, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.60305825860578, 92.96406798204066, 93.04257424295116, 93.42330992183737, 95.07040852736313, 97.98757855746832, 100.46722089443305, 106.06966088846048, 111.15121172274988, 112.14455804210392, 113.3904383720207, 131.16812982567123, 131.2248013481731, 132.36263999033352, 144.87247712063777, 145.5790336435578, 153.24250883340224, 153.45086344292946, 159.92414241280906, 178.86920308819714, 194.9475881773768, 200.25436817424804]
#
# Current iteration : 29
# Time taken by far : 7.9 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 84.04135476328173, 84.08454004525744, 86.4737646338654, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.60305825860578, 92.96406798204066, 93.04257424295116, 93.42330992183737, 98.62908327410838, 101.36352231851191, 102.03501200540374, 111.15121172274988, 111.9083374578272, 119.17213568947217, 119.18425365772057, 120.31940076742711, 120.57613127003239, 122.53714376658809, 136.0038159309308, 151.78973346099167, 154.6112957920802, 163.33485109142768, 178.86920308819714, 190.0133899545558, 194.9475881773768]
#
# Current iteration : 30
# Time taken by far : 8.1 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [82.41146268328428, 84.04135476328173, 84.08454004525744, 86.39227589245293, 86.4737646338654, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.60305825860578, 92.96406798204066, 93.04257424295116, 100.29620525115254, 101.36352231851191, 107.39464462644429, 108.3555882180141, 110.80601230395155, 113.22257654621606, 115.43579428396892, 115.6441035823894, 116.37318111788476, 116.72311540982462, 120.57613127003239, 154.6112957920802, 154.6112957920802, 180.91646681270487, 190.0133899545558, 192.79462894484757, 200.84348872099682]
#
# Current iteration : 31
# Time taken by far : 8.4 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [78.16781264052584, 82.41146268328428, 84.04135476328173, 84.08454004525744, 85.67130649433523, 86.39227589245293, 86.4737646338654, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.60305825860578, 92.96406798204066, 94.59501212853614, 98.76574424629624, 102.15118204211407, 102.27148863218311, 105.49951851564808, 113.22257654621606, 114.18633032217826, 119.23385851532029, 127.82234112940905, 131.88136828964286, 132.95495715745167, 134.29120880836038, 144.78953145021876, 147.45119827464407, 162.02831797436062, 164.48964989725891]
#
# Current iteration : 32
# Time taken by far : 8.7 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [78.16781264052584, 82.41146268328428, 84.04135476328173, 84.08454004525744, 84.82197817028734, 85.67130649433523, 86.39227589245293, 86.4737646338654, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 91.28385126321383, 92.26347158651352, 92.60305825860578, 92.60305825860578, 96.19752572853429, 98.78412569833276, 102.27148863218311, 102.8487500832715, 112.66295075124756, 113.22257654621606, 124.42994891079576, 126.46713670202065, 134.6765941288722, 158.06863262720157, 159.1523506151641, 162.02831797436062, 164.48964989725891, 183.2478500742249]
#
# Current iteration : 33
# Time taken by far : 9.0 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [78.16781264052584, 80.9400757774298, 81.29260881791379, 82.41146268328428, 84.04135476328173, 84.08454004525744, 84.82197817028734, 85.67130649433523, 86.39227589245293, 86.4737646338654, 87.19786642287337, 87.67788055997812, 89.4430737388695, 90.53482924346514, 91.10373016535279, 92.60305825860578, 93.04772740472137, 98.78412569833276, 103.25209222453343, 109.71627635264628, 112.13548343968634, 113.22257654621606, 113.22257654621606, 116.16124824833254, 117.36705492774512, 122.65488685068624, 134.6765941288722, 149.25501126060422, 164.48964989725891, 176.5346817833397]
#
# Current iteration : 34
# Time taken by far : 9.3 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [78.16781264052584, 80.9400757774298, 81.29260881791379, 82.41146268328428, 82.49700750230899, 84.04135476328173, 84.08454004525744, 84.82197817028734, 85.67130649433523, 86.39227589245293, 86.4737646338654, 87.19786642287337, 87.67788055997812, 88.12486028122562, 92.4786767765233, 92.60305825860578, 92.74931374096151, 102.71422398914487, 106.54009713816285, 108.5882402972555, 113.07501830590877, 113.22257654621606, 117.36705492774512, 126.20992635639037, 139.44053477963269, 143.91698789599783, 148.64455494416595, 159.2118307364368, 162.04820559966592, 164.72210483181675]
#
# Current iteration : 35
# Time taken by far : 9.6 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [78.16781264052584, 80.9400757774298, 81.29260881791379, 82.41146268328428, 82.49700750230899, 84.04135476328173, 84.08454004525744, 84.82197817028734, 85.67130649433523, 86.39227589245293, 86.4737646338654, 87.19786642287337, 87.9602312859964, 88.12486028122562, 92.60305825860578, 94.04743732367344, 99.6047440710579, 102.43978713724962, 106.92351921174382, 108.5882402972555, 113.07501830590877, 114.57964886253454, 115.57048438940986, 117.36705492774512, 127.63997609651351, 136.6372655454537, 139.44053477963269, 146.6764960062216, 148.64455494416595, 152.54321497980786]
#
# Current iteration : 36
# Time taken by far : 9.9 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [78.16781264052584, 80.9400757774298, 81.29260881791379, 81.90717804239497, 82.41146268328428, 82.49700750230899, 84.04135476328173, 84.08454004525744, 84.82197817028734, 85.67130649433523, 86.39227589245293, 86.4737646338654, 87.19786642287337, 87.57393149883158, 91.3281331084208, 91.66406064181393, 92.29865827800613, 93.44332045896978, 97.07571019709081, 100.86201912391343, 105.32587897659621, 120.00031054253789, 127.63997609651351, 128.96233265116297, 130.6599693315344, 135.86770911170373, 146.6764960062216, 148.64455494416595, 149.7807608666195, 176.17969738061046]
#
# Current iteration : 37
# Time taken by far : 10.2 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [68.00618141051194, 75.49372345988745, 75.63801319617988, 78.16781264052584, 80.9400757774298, 81.29260881791379, 81.63673672349854, 81.90717804239497, 82.41146268328428, 82.49700750230899, 84.04135476328173, 84.08454004525744, 84.82197817028734, 85.67130649433523, 86.17091035884268, 86.39227589245293, 86.4737646338654, 88.36555063756401, 88.47121610281675, 88.79328969256171, 92.24320181857388, 100.16577762453524, 100.86201912391343, 101.24562603636016, 113.71432400749973, 113.99734105062943, 115.7304718938338, 148.29505562785005, 182.88077258482383, 202.50420443945657]
#
# Current iteration : 38
# Time taken by far : 10.4 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [68.00618141051194, 73.87387544936938, 75.49372345988745, 75.63801319617988, 78.16781264052584, 80.9400757774298, 81.29260881791379, 81.63673672349854, 81.90717804239497, 82.41146268328428, 82.49700750230899, 84.04135476328173, 84.08454004525744, 85.27010379336495, 85.67130649433523, 88.36555063756401, 88.95779342975902, 96.92850637479114, 100.1561609320379, 100.71263103172417, 101.03151547329514, 101.24562603636016, 108.86779367992618, 109.03448366206798, 123.22163847411187, 123.25165354651658, 131.61992993001013, 158.4027514605016, 182.88077258482383, 188.96978760804248]
#
# Current iteration : 39
# Time taken by far : 10.7 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [68.00618141051194, 71.0449685272639, 73.87387544936938, 75.49372345988745, 75.63801319617988, 78.16781264052584, 80.9400757774298, 81.29260881791379, 81.63673672349854, 81.90717804239497, 82.41146268328428, 82.49700750230899, 84.04135476328173, 84.70493344428075, 85.27010379336495, 85.67130649433523, 86.11079943690633, 90.21297487926265, 92.26411819840918, 94.44731166142243, 94.7258996386686, 95.31089083199555, 102.52656992061544, 104.33865464886681, 105.14647394840874, 109.17687644350328, 123.22163847411187, 131.1805327875605, 144.1188322508963, 178.04390747557767]
#
# Current iteration : 40
# Time taken by far : 10.9 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [68.00618141051194, 71.0449685272639, 73.87387544936938, 75.49372345988745, 75.63801319617988, 78.16781264052584, 80.9400757774298, 81.29260881791379, 81.55070477365078, 81.63673672349854, 81.90717804239497, 82.41146268328428, 82.49700750230899, 84.04135476328173, 94.44731166142243, 94.7258996386686, 95.31089083199555, 99.12813870689793, 102.52656992061544, 104.33865464886681, 105.15153314705691, 109.63839508847634, 112.02764426714299, 118.38769550877022, 123.51623481580887, 125.51637087801438, 144.1188322508963, 145.5552249021188, 151.74831928732394, 185.2069492164076]
#
# Current iteration : 41
# Time taken by far : 11.2 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [68.00618141051194, 71.0449685272639, 73.87387544936938, 75.49372345988745, 75.63801319617988, 78.16781264052584, 79.40918797503136, 80.9400757774298, 81.29260881791379, 81.55070477365078, 81.63673672349854, 81.90717804239497, 82.41146268328428, 84.63311162667549, 85.94412474307728, 86.0474027662716, 88.90838274169886, 95.79913728528702, 97.50646664429037, 98.51525062664224, 100.1118965976459, 105.72733025035376, 106.91236026438774, 108.7580160552273, 109.63942287909714, 110.32488009661695, 114.06987087432682, 118.38769550877022, 125.51637087801438, 125.51637087801438]
#
# Current iteration : 42
# Time taken by far : 11.5 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [68.00618141051194, 71.0449685272639, 73.87387544936938, 75.49372345988745, 75.63801319617988, 78.16781264052584, 79.40918797503136, 80.9400757774298, 81.29260881791379, 81.55070477365078, 81.63673672349854, 81.90717804239497, 85.75651854773619, 85.77014927268488, 86.0474027662716, 93.2128180137951, 96.53476491234329, 97.03337869268921, 99.3702983010225, 105.37817061980942, 110.80348934178193, 112.92014470333854, 113.42590382389668, 116.0524181640635, 138.32092715313843, 139.94317254697077, 142.7139049159208, 155.0664918027672, 160.69725138226184, 162.44877248948964]
#
# Current iteration : 43
# Time taken by far : 11.7 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [68.00618141051194, 71.0449685272639, 73.87387544936938, 75.49372345988745, 75.63801319617988, 78.16781264052584, 79.40918797503136, 80.9400757774298, 81.29260881791379, 81.55070477365078, 81.63673672349854, 81.72272991587955, 81.90717804239497, 89.24754727041, 96.53476491234329, 103.51762324797328, 108.97729666532649, 110.47283632311417, 111.9647648210042, 112.92014470333854, 113.42590382389668, 116.0524181640635, 141.43178213161607, 155.0664918027672, 159.42460048234875, 160.38713925906586, 160.69725138226184, 162.44877248948964, 167.4249392996782, 187.4470158858676]
#
# Current iteration : 44
# Time taken by far : 12.0 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [68.00618141051194, 71.0449685272639, 73.87387544936938, 75.49372345988745, 75.63801319617988, 78.16781264052584, 79.40918797503136, 80.9400757774298, 81.29260881791379, 81.55070477365078, 81.63673672349854, 81.72272991587955, 100.85152473764124, 100.96052696160773, 101.5380040340948, 103.09342808232758, 103.12233693013617, 104.21033233288713, 111.03383573483244, 117.93275105874079, 123.93023397701856, 134.8123043161359, 139.96986609555148, 143.68675980281435, 144.51871255023812, 148.72115302349323, 157.9341338440488, 158.81489011238256, 160.38713925906586, 163.46548989163972]
#
# Current iteration : 45
# Time taken by far : 12.2 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 75.49372345988745, 75.63801319617988, 76.85899603958725, 78.16781264052584, 79.40918797503136, 80.9400757774298, 81.11409898915379, 81.29260881791379, 81.55070477365078, 81.63673672349854, 81.72272991587955, 90.2208180630846, 92.97367554009642, 101.5380040340948, 101.5380040340948, 103.09342808232758, 103.12233693013617, 104.21033233288713, 113.27861534327232, 116.76695036428532, 119.47104852034175, 129.9499593749606, 141.90158311749911, 231.04651110539888]
#
# Current iteration : 46
# Time taken by far : 12.5 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 75.49372345988745, 75.63801319617988, 76.85899603958725, 78.16781264052584, 78.64911540252366, 79.40918797503136, 79.43814928031765, 80.9400757774298, 81.55070477365078, 81.55070477365078, 82.93190651374185, 87.43199123513331, 87.54366779705434, 90.2208180630846, 90.53549253936633, 90.95095595027556, 91.59803852898634, 97.3370959783738, 103.74958611040717, 104.0960799449281, 112.73904610686138, 112.93881531540991, 119.47104852034175, 129.9499593749606]
#
# Current iteration : 47
# Time taken by far : 12.8 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 75.49372345988745, 75.63801319617988, 76.85899603958725, 78.16781264052584, 78.64911540252366, 79.40918797503136, 81.10229624105553, 81.55070477365078, 83.81159626557998, 87.08158748987523, 90.2208180630846, 93.56697838150704, 94.0619589087583, 95.40412154704275, 95.55362181773995, 97.3370959783738, 103.45462339791294, 104.30574272737009, 104.84633564204174, 116.2145273208876, 126.48990309979068, 129.06600557287712, 140.53467318445396, 157.5188777642367]
#
# Current iteration : 48
# Time taken by far : 13.0 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 75.49372345988745, 75.63801319617988, 76.85899603958725, 77.10739278587828, 78.16781264052584, 78.64911540252366, 78.671321961718, 79.40918797503136, 83.33177266909708, 83.81159626557998, 84.9854646862723, 87.08158748987523, 89.17373796068306, 90.23246886906495, 95.55362181773995, 95.55362181773995, 96.25608874156751, 100.85155174224202, 101.07143720894058, 104.81362129495194, 107.33934868051729, 114.34670393477978, 127.93635687302681, 128.38751489348073]
#
# Current iteration : 49
# Time taken by far : 13.2 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 75.49372345988745, 75.63801319617988, 76.85899603958725, 77.10739278587828, 78.16781264052584, 78.64911540252366, 78.89832945706267, 81.62038931652638, 85.81121597414261, 90.59439332444609, 91.72898420815072, 91.83128594545865, 103.67037184229734, 104.81362129495194, 105.42593557708058, 105.76105094505535, 107.71016593195603, 117.92230642203535, 127.93635687302681, 128.38751489348073, 141.17075500434348, 153.02182661199558, 159.44905838992113, 160.53940368334506]
#
# Current iteration : 50
# Time taken by far : 13.5 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 74.00631408309403, 75.49372345988745, 75.63801319617988, 76.85899603958725, 77.10739278587828, 78.16781264052584, 78.64911540252366, 81.3396853373905, 85.08551359008675, 85.10111464618137, 87.66266239634997, 91.95907260171393, 98.62248210455263, 99.42318754731707, 100.68791332555962, 105.42593557708058, 108.99338697084454, 109.06686839315677, 109.30233942828187, 110.45115789411601, 114.65123803500423, 114.8765574689632, 125.1667256106944, 131.10039592692956]
#
# Current iteration : 51
# Time taken by far : 13.8 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 68.10964852048355, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 74.00631408309403, 75.49372345988745, 75.63801319617988, 76.85899603958725, 77.10739278587828, 78.16781264052584, 81.63132485389788, 84.65650099891393, 85.08551359008675, 86.08050177815302, 87.66266239634997, 88.64872245738755, 91.76456317900029, 91.95907260171393, 94.22542109934267, 95.37035910442322, 96.93724323850242, 100.68791332555962, 105.42593557708058, 109.30233942828187, 111.8685855498449, 115.86858436920681, 129.68234450590666]
#
# Current iteration : 52
# Time taken by far : 14.0 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 68.10964852048355, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 74.00631408309403, 75.49372345988745, 75.63801319617988, 76.85899603958725, 77.10739278587828, 79.28804795896049, 84.12448537489345, 84.34253300887573, 87.10276783661318, 91.90235335110376, 92.94577867335083, 94.0829294289143, 99.28707381101259, 101.7384285159947, 109.30233942828187, 112.29520013124257, 112.44459537154854, 116.55966778101434, 116.6657507177057, 125.83477009494104, 129.76569859885421, 139.7402039772132, 146.92537562286105]
#
# Current iteration : 53
# Time taken by far : 14.3 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 68.10964852048355, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 74.00631408309403, 75.49372345988745, 75.63801319617988, 76.85899603958725, 77.10739278587828, 77.12017474649356, 83.36127886397512, 84.12448537489345, 87.5287155443639, 91.90235335110376, 93.31063932118964, 94.0829294289143, 95.61413233229258, 99.28707381101259, 100.86144338694349, 101.7384285159947, 103.92931429432377, 108.6763302548338, 112.06700637312518, 120.38328326721948, 122.38481009850088, 135.69010291561196, 163.52776765208645]
#
# Current iteration : 54
# Time taken by far : 14.5 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 68.10964852048355, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 74.00631408309403, 74.74335737485114, 75.49372345988745, 75.63801319617988, 76.85899603958725, 77.10739278587828, 80.16785456274725, 83.36127886397512, 84.14684202034528, 96.27353042033904, 98.86770899535057, 100.86144338694349, 101.7384285159947, 103.92931429432377, 104.52060776045106, 110.51494339231047, 119.98608492857522, 120.38328326721948, 120.38328326721948, 121.50426808011782, 128.92517072451236, 129.5209201255796, 137.07047375901143]
#
# Current iteration : 55
# Time taken by far : 14.8 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 68.10964852048355, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 74.00631408309403, 74.74335737485114, 75.49372345988745, 75.63801319617988, 76.85899603958725, 77.10739278587828, 77.66884123781759, 86.33994783310936, 88.70221862495579, 91.48535427342964, 99.6799112245501, 102.28480487812624, 104.52060776045106, 115.7850220929726, 117.24623162221543, 127.08415440170549, 129.5209201255796, 130.99152139342192, 132.5210448314127, 137.07047375901143, 141.30042726699008, 143.43419795677016, 145.54780202366908]
#
# Current iteration : 56
# Time taken by far : 15.0 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 68.10964852048355, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 74.00631408309403, 74.74335737485114, 75.11017559051179, 75.49372345988745, 75.63801319617988, 76.85899603958725, 91.6469872498933, 95.7066008614264, 95.85647257455588, 97.56812394131654, 102.28480487812624, 119.08719176293657, 122.11721196869682, 124.29804174987693, 126.37768303644238, 126.48968278268875, 127.08415440170549, 127.08415440170549, 128.16311463067632, 128.5591712585507, 143.22188244266968, 145.54780202366908, 177.73288423231517]
#
# Current iteration : 57
# Time taken by far : 15.2 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 68.00618141051194, 68.10964852048355, 71.0449685272639, 73.27510025754901, 73.61539604661617, 73.87387544936938, 74.00631408309403, 74.74335737485114, 75.11017559051179, 75.49372345988745, 75.63801319617988, 79.76805077057925, 85.99933187405261, 91.6469872498933, 97.56812394131654, 101.42303589102437, 102.5657916970976, 107.0941232571252, 108.07177880504867, 116.29239894992313, 121.41345350026172, 122.11721196869682, 124.81803089948568, 126.37768303644238, 127.08415440170549, 127.08415440170549, 127.08415440170549, 128.7017604717032, 151.16066132733042]
#
# Current iteration : 58
# Time taken by far : 15.5 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 67.77034818778091, 68.00618141051194, 68.10964852048355, 71.0449685272639, 72.51352478150024, 73.27510025754901, 73.61539604661617, 73.87387544936938, 74.00631408309403, 74.74335737485114, 75.11017559051179, 75.49372345988745, 75.63801319617988, 85.55642852059106, 86.13329212522709, 88.56370876932756, 91.6469872498933, 96.58947790698356, 104.45417183634324, 107.42150259076679, 110.78381285199787, 112.42252520365088, 122.11721196869682, 125.35587429658314, 126.37768303644238, 128.04487479619155, 129.06084969032773, 129.35553864337604, 151.4258642433924]
#
# Current iteration : 59
# Time taken by far : 15.7 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 67.77034818778091, 68.00618141051194, 68.10964852048355, 69.55611644777005, 71.0449685272639, 72.51352478150024, 73.27510025754901, 73.3162324555495, 73.61539604661617, 73.87387544936938, 74.00631408309403, 74.74335737485114, 75.11017559051179, 75.49372345988745, 84.23625452329311, 86.13329212522709, 90.43929095309743, 99.18526527023708, 103.05442637318878, 110.78381285199787, 111.0932859126808, 112.42252520365088, 120.25299802092644, 124.64020398907275, 125.35587429658314, 131.330704293811, 151.4258642433924, 152.6843118681157, 176.2285458201901]
#
# Current iteration : 60
# Time taken by far : 16.0 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 67.77034818778091, 68.00618141051194, 68.10964852048355, 69.55611644777005, 71.0449685272639, 72.51352478150024, 73.27510025754901, 73.3162324555495, 73.61539604661617, 73.87387544936938, 74.00631408309403, 74.74335737485114, 75.49372345988745, 84.23625452329311, 86.13329212522709, 87.31046220145204, 90.21952995408984, 90.36296634594589, 90.43929095309743, 93.49487236938207, 93.69509905524403, 93.69776504178041, 99.18526527023708, 102.5979412714973, 103.05442637318878, 108.52890594422767, 110.39148463113706, 127.92962802700977, 131.3578172917433]
#
# Current iteration : 61
# Time taken by far : 16.2 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 67.77034818778091, 68.00618141051194, 68.10964852048355, 69.55611644777005, 71.0449685272639, 72.51352478150024, 73.27510025754901, 73.3162324555495, 73.61539604661617, 73.87387544936938, 74.00631408309403, 75.49372345988745, 77.02452912509207, 85.45789076533133, 86.65476808734884, 88.98471651369584, 90.20217519093805, 92.86761999586312, 94.15636149918089, 96.9389215657472, 97.04379330112016, 98.19023716527579, 100.28858573098508, 104.9171564357071, 107.00178296630851, 108.52890594422767, 112.17283828002478, 121.80884785346217, 159.97990710339502]
#
# Current iteration : 62
# Time taken by far : 16.5 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 67.77034818778091, 68.00618141051194, 68.10964852048355, 69.15445589406069, 69.55611644777005, 70.86253002809063, 71.0449685272639, 71.52734183321874, 72.51352478150024, 73.27510025754901, 73.3162324555495, 73.61539604661617, 73.87387544936938, 74.00631408309403, 85.45789076533133, 85.45789076533133, 90.08734042940122, 92.86761999586312, 94.15636149918089, 94.15636149918089, 94.65985095114407, 96.87815336958235, 96.9389215657472, 100.70114375141132, 101.07237503054809, 101.11297495676196, 104.9171564357071, 107.6834081697042, 126.95492723074075]
#
# Current iteration : 63
# Time taken by far : 16.7 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 67.77034818778091, 67.92401678992694, 68.00618141051194, 68.10964852048355, 69.15445589406069, 69.55611644777005, 70.86253002809063, 71.0449685272639, 71.52734183321874, 72.51352478150024, 73.27510025754901, 73.3162324555495, 74.53044274023202, 74.71437326383388, 77.38964382505054, 78.51950625772227, 80.48367834110897, 86.67663082363335, 91.26841126825482, 93.17159364344926, 97.46034770993148, 97.52799925642755, 101.02991533134157, 109.47324830500224, 110.8212317782711, 120.96617681236569, 125.54849314506988, 126.09169570296362, 167.99075959413412]
#
# Current iteration : 64
# Time taken by far : 17.0 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 67.77034818778091, 67.92401678992694, 68.00618141051194, 68.10964852048355, 69.15445589406069, 69.55611644777005, 70.25304242173421, 70.86253002809063, 71.0449685272639, 71.52734183321874, 72.04624268550562, 72.51352478150024, 73.27510025754901, 81.1932552049268, 86.67663082363335, 89.17941594858745, 91.0015958119601, 93.528856656193, 94.61001172518857, 104.45285588484104, 107.28908904279646, 110.45768490528458, 111.59937498812663, 113.56423182201627, 119.05420141895877, 125.57654505987584, 125.76021020726007, 135.8096910481042, 156.9448894956335]
#
# Current iteration : 65
# Time taken by far : 17.2 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 67.77034818778091, 67.92401678992694, 68.00618141051194, 68.10964852048355, 69.15445589406069, 69.55611644777005, 70.25304242173421, 70.86253002809063, 71.0449685272639, 71.52734183321874, 72.04624268550562, 75.08828661419388, 78.22884703452054, 79.27219758296012, 81.1932552049268, 81.1932552049268, 82.51902582763498, 83.77352214582417, 91.53871096637299, 96.13436750910736, 102.41140167861994, 104.24287265550674, 110.45768490528458, 111.59937498812663, 111.59937498812663, 113.56423182201627, 154.81838942478768, 156.9448894956335, 160.79919100852965]
#
# Current iteration : 66
# Time taken by far : 17.5 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 67.77034818778091, 67.92401678992694, 68.00618141051194, 68.10964852048355, 69.15445589406069, 69.16223739375789, 69.55611644777005, 70.15243653806834, 70.25304242173421, 70.86253002809063, 71.0449685272639, 71.52734183321874, 72.04624268550562, 73.76595078486795, 75.65161634966226, 78.98711472624439, 82.51320009086656, 87.20620763425056, 87.79109327210689, 88.95747680316894, 90.4004338004813, 90.64038388357258, 94.71243219504673, 101.49748293468409, 114.57829550484801, 122.92543890675275, 125.05130887678773, 129.689517837826, 138.5131046671781]
#
# Current iteration : 67
# Time taken by far : 17.8 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# ...
#
# Current iteration : 79
# Time taken by far : 20.8 seconds
# Current top member's network accuracy: 70.42%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 65.26118809426903, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 68.10964852048355, 69.15445589406069, 69.16223739375789, 69.51359354780536, 70.21199379171597, 71.78792923648413, 77.64660016377552, 79.98999295106152, 81.07235776755445, 84.83059555416057, 87.43593139657654, 87.43593139657654, 88.52201639646425, 91.63107523087324, 98.9161764114676, 98.98369641390437, 132.3003457649251, 143.1452519601065, 152.4032530658306, 159.94325696196822, 185.46480096229303, 197.75301323825983]
#
# Current iteration : 80
# Time taken by far : 21.0 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 65.26118809426903, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 68.10964852048355, 69.15445589406069, 69.16223739375789, 69.51359354780536, 70.21199379171597, 70.21199379171597, 71.78792923648413, 71.78792923648413, 78.77808458470841, 79.98999295106152, 80.83735515386334, 82.71857984750324, 83.30730707358316, 84.83059555416057, 90.61126593177599, 92.97002999777456, 101.86155941929984, 102.61271098560316, 121.29782239547986, 122.10309900057787, 146.53457213910096, 159.94325696196822]
#
# Current iteration : 81
# Time taken by far : 21.3 seconds
# Current top member's network accuracy: 68.31%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 63.92091625729272, 65.26118809426903, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 68.046723524779, 68.10964852048355, 69.15445589406069, 69.16223739375789, 69.51359354780536, 70.21199379171597, 71.61639645273695, 71.85372532420074, 79.6356881917383, 80.76451108206936, 82.9873783454375, 83.34976718954358, 86.07239773804923, 92.35268359458445, 92.49830552432074, 96.53289105045603, 106.27424520461564, 139.52150066563306, 153.44336713116905, 154.19165728294467, 160.26520922216477]
#
# Current iteration : 82
# Time taken by far : 21.5 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 63.92091625729272, 65.26118809426903, 66.41749364542206, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 68.046723524779, 68.10964852048355, 68.13783193243121, 69.15445589406069, 73.95607065904397, 74.98256556474912, 77.06658635803848, 80.31962888082914, 86.07239773804923, 87.72869787700702, 94.38429102676227, 106.14538712756514, 113.65295955751367, 119.14272040761911, 120.76188796057791, 140.7102241105706, 144.763284202807, 153.44336713116905, 153.9904843806751, 154.31565965980263]
#
# Current iteration : 83
# Time taken by far : 21.8 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 63.92091625729272, 65.26118809426903, 66.41749364542206, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 68.046723524779, 68.10964852048355, 68.13783193243121, 73.30868557538189, 73.95607065904397, 84.97144648804812, 85.3379166257093, 87.72869787700702, 87.94021509426742, 91.90146487842674, 92.4027686055463, 100.47044461665394, 102.30688812332077, 108.32670563030504, 115.324406313667, 117.39684303913202, 119.14272040761911, 136.7211824656741, 140.7102241105706, 185.29661657297004]
#
# Current iteration : 84
# Time taken by far : 22.0 seconds
# Current top member's network accuracy: 69.01%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 63.92091625729272, 65.26118809426903, 66.25789836382232, 66.41749364542206, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 68.046723524779, 68.10964852048355, 69.5568265801247, 69.71062063199705, 71.11954768829067, 72.49861463524068, 74.74235265165784, 75.17491249653266, 77.17697890437141, 80.27659602212991, 85.95097996882161, 87.72869787700702, 91.90146487842674, 94.06913931313362, 96.1062722814279, 98.64650073207552, 107.84864470055514, 113.72071521053086, 127.74477821090849]
#
# Current iteration : 85
# Time taken by far : 22.3 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.92091625729272, 65.26118809426903, 66.25789836382232, 66.41749364542206, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 68.046723524779, 69.71062063199705, 72.49861463524068, 73.21093878522429, 74.1796075062925, 74.39198566388467, 80.05282385916736, 84.5258851483806, 85.97944312980724, 91.86401291329594, 91.90146487842674, 94.06913931313362, 114.35083513017747, 122.17271121962617, 128.8190862411261, 130.04186775270819, 137.5391843780612, 146.92800974201697]
#
# Current iteration : 86
# Time taken by far : 22.5 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.92091625729272, 65.26118809426903, 66.25789836382232, 66.41749364542206, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 69.71062063199705, 74.1796075062925, 75.06498942365555, 75.77876397488986, 76.84732117633693, 81.75978262182338, 83.5293269563532, 86.77317190692246, 89.6538064307251, 92.6689252128949, 97.86523238169245, 100.46969118685632, 121.22630789840301, 122.17271121962617, 130.04186775270819, 149.80392840910272, 150.6847656685087, 162.83432475971034]
#
# Current iteration : 87
# Time taken by far : 22.8 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.92091625729272, 65.26118809426903, 66.25789836382232, 66.41749364542206, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 74.1796075062925, 74.1985002797472, 76.84732117633693, 76.85242827959254, 78.0891149056351, 78.38041506102104, 78.42122857111072, 86.77317190692246, 90.49721198990673, 93.9310169619232, 101.51999455766875, 103.1305515951047, 105.0092512980057, 111.83955780257998, 130.04186775270819, 146.0317973863582, 149.72278314447155, 152.81479249302382]
#
# Current iteration : 88
# Time taken by far : 23.1 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.92091625729272, 65.26118809426903, 66.25789836382232, 66.41749364542206, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 71.4122759244328, 73.12377456486831, 74.1796075062925, 74.1985002797472, 75.45503191740904, 76.84732117633693, 77.01965483579214, 78.42122857111072, 80.38179325837156, 82.15619057437159, 87.04760688366245, 89.76831071280095, 96.88880865194284, 137.3878948510162, 150.70611559107547, 152.81479249302382, 152.81479249302382, 173.97726911267773]
#
# Current iteration : 89
# Time taken by far : 23.3 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.16458665977007, 63.92091625729272, 65.26118809426903, 65.46625823157892, 66.25789836382232, 66.41749364542206, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 67.92401678992694, 68.00618141051194, 68.09733714488718, 68.23139068813143, 71.4122759244328, 72.02627079043452, 74.91539957358808, 78.9470439994811, 81.49903407341915, 83.21346945506923, 84.09107050304299, 86.60302804497564, 88.91356028930625, 99.12856093916615, 105.46123712515708, 110.06316469923337, 112.38679932944102, 125.28792536659903]
#
# Current iteration : 90
# Time taken by far : 23.6 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.16458665977007, 63.92091625729272, 65.26118809426903, 65.46625823157892, 66.25789836382232, 66.41749364542206, 67.1409971802863, 67.65596451349316, 67.75518238805985, 67.77034818778091, 67.89292697005862, 68.00618141051194, 68.00618141051194, 69.77016386227521, 70.31291050906555, 71.4122759244328, 71.51885998028942, 74.91539957358808, 80.74834849791057, 83.21346945506923, 89.67378265975269, 94.52777181447516, 95.66991034263957, 102.0020065017451, 111.84277537371037, 116.5852782017244, 125.28792536659903, 136.8413446452791]
#
# Current iteration : 91
# Time taken by far : 23.8 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.16458665977007, 63.92091625729272, 65.26118809426903, 65.46625823157892, 66.25789836382232, 66.41749364542206, 67.1409971802863, 67.65596451349316, 67.75518238805985, 67.77034818778091, 69.77016386227521, 74.91539957358808, 79.71653241927326, 80.74834849791057, 80.74834849791057, 81.20423471096642, 82.89685857681096, 87.24570671785538, 89.67378265975269, 93.30423546351784, 106.46384055360447, 111.45817984881458, 113.90553274383407, 116.5852782017244, 116.5852782017244, 117.10673007181478, 120.8631611002302, 132.15677191427827]
#
# Current iteration : 92
# Time taken by far : 24.0 seconds
# Current top member's network accuracy: 70.42%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.16458665977007, 63.92091625729272, 65.26118809426903, 65.46625823157892, 66.25789836382232, 66.41749364542206, 66.97172557561521, 67.1409971802863, 67.65596451349316, 67.75518238805985, 67.77034818778091, 69.86404932696138, 76.82305851884654, 79.71653241927326, 80.74834849791057, 81.20423471096642, 82.68868458268254, 82.81093075835018, 86.30732974567192, 87.32197070473485, 89.45551897343228, 89.54411132816614, 89.67378265975269, 98.99606385047127, 99.78301223290886, 104.55260341917251, 106.99048577950938, 120.8631611002302]
#
# Current iteration : 93
# Time taken by far : 24.3 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.16458665977007, 63.26014621300549, 63.92091625729272, 65.26118809426903, 65.46625823157892, 66.25789836382232, 66.41749364542206, 66.48760952805353, 66.97172557561521, 67.1409971802863, 67.65596451349316, 67.75518238805985, 67.77034818778091, 71.29236120783112, 75.73558048195957, 75.99751192439159, 77.7850615017496, 78.87452063699659, 81.23273577845686, 89.45551897343228, 90.10381634920414, 99.41424819240216, 99.78301223290886, 99.78301223290886, 104.55260341917251, 104.55260341917251, 118.29569247163369, 118.48710433884648]
#
# Current iteration : 94
# Time taken by far : 24.5 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.16458665977007, 63.26014621300549, 63.92091625729272, 65.26118809426903, 65.46625823157892, 65.648869845695, 66.05579150516739, 66.25789836382232, 66.41749364542206, 66.48760952805353, 66.97172557561521, 67.1409971802863, 67.75518238805985, 69.1107843981575, 73.3109373732323, 75.73558048195957, 75.73558048195957, 76.31532895371299, 79.9207746880025, 81.23273577845686, 81.35601618222441, 83.70189186250974, 87.69423871463131, 90.10381634920414, 90.38914459530204, 115.98830526804336, 117.02191936896666, 149.8310210581388]
#
# Current iteration : 95
# Time taken by far : 24.8 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 63.16458665977007, 63.26014621300549, 63.92091625729272, 65.26118809426903, 65.46625823157892, 65.648869845695, 66.05579150516739, 66.25789836382232, 66.41749364542206, 66.48760952805353, 71.82895187243058, 73.64316523058024, 75.73558048195957, 76.01528412019955, 77.88853714187223, 77.91778784501768, 78.02632582655954, 81.6439482468798, 82.78885300046116, 86.12788318446302, 91.33996729986539, 93.30524685924854, 95.09377695753128, 98.19635368600271, 104.81032781935458, 122.70490897734797, 149.44162294762864, 149.4894053902017]
#
# Current iteration : 96
# Time taken by far : 25.0 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 62.606410590858445, 63.16458665977007, 63.26014621300549, 63.92091625729272, 64.79297402663012, 65.26118809426903, 65.46625823157892, 65.52700091506625, 65.59018606546837, 65.648869845695, 66.05579150516739, 66.25374827707569, 66.25789836382232, 66.41749364542206, 66.48760952805353, 67.45638770568665, 70.75658117086365, 71.1183063223704, 72.03620112470901, 73.57529108600485, 74.44601995291553, 76.00139189510263, 79.08649552866291, 82.63137143333431, 91.96075111360692, 93.59179710942644, 96.49823512843817, 114.84527466684524]
#
# Current iteration : 97
# Time taken by far : 25.3 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 62.606410590858445, 63.16458665977007, 63.26014621300549, 63.92091625729272, 64.79297402663012, 65.26118809426903, 65.46625823157892, 65.52700091506625, 65.59018606546837, 65.648869845695, 66.05579150516739, 66.25789836382232, 71.66580432587153, 74.34752712615544, 74.44601995291553, 75.62034405338841, 76.62253505469792, 79.35104257344759, 79.85574848987257, 82.63137143333431, 84.23038693567356, 90.61984775633536, 94.3936185887798, 101.07968595086875, 104.62318241495237, 115.33006271464012, 131.46692245837195, 172.34574479706646]
#
# Current iteration : 98
# Time taken by far : 25.6 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [61.83813144260356, 62.07306867806196, 62.606410590858445, 63.16458665977007, 63.26014621300549, 63.92091625729272, 64.79297402663012, 65.26118809426903, 65.46625823157892, 65.52700091506625, 65.59018606546837, 65.59137913537727, 65.648869845695, 68.15944524215588, 69.38781983159728, 70.83804410766318, 73.31821959215918, 73.58564630467137, 75.32362963811522, 75.40334891643633, 87.32856123152727, 88.43756682606931, 100.80856750347748, 100.99260942340122, 103.46602201401461, 107.3649518420148, 126.59219827417036, 142.5808189928539, 143.16984947392706, 143.60058257051884]
#
# Current iteration : 99
# Time taken by far : 25.9 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [59.321328695929, 61.83813144260356, 62.07306867806196, 62.606410590858445, 63.16458665977007, 63.26014621300549, 63.92091625729272, 64.79297402663012, 65.26118809426903, 65.46625823157892, 65.52700091506625, 65.59018606546837, 65.59137913537727, 65.99760917573725, 68.5875885764371, 70.83804410766318, 75.13503794301072, 78.15740106031376, 81.44080434270921, 83.78904021511177, 83.8730557048278, 85.47614783312306, 89.0683927926903, 89.51121365099749, 90.04149870763584, 92.19185660917218, 97.8238810471066, 100.80856750347748, 126.59219827417036, 144.60792335739916]
#
# Current iteration : 100
# Time taken by far : 26.2 seconds
# Current top member's network accuracy: 69.72%
#
# Sorted Score List
# Sorted Score: [59.321328695929, 61.68101782865576, 61.83813144260356, 62.07306867806196, 62.355387823687195, 62.606410590858445, 63.16458665977007, 63.26014621300549, 63.92091625729272, 64.79297402663012, 65.13155246109177, 65.26118809426903, 65.46625823157892, 65.52700091506625, 65.59018606546837, 65.99829617676424, 72.64115089018077, 72.70449768056784, 73.65398364120922, 75.67303169403425, 76.08679227869563, 80.71377002823506, 85.35413756417279, 89.22201227644584, 97.8238810471066, 114.96748540159439, 117.44135953108085, 118.19045689904047, 118.54254976361788, 149.16708826049307]
